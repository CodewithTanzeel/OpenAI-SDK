# %%
# !pip install -q -U google-generativeai

# %%
# !pip install -Uq openai-agents

# %%
from google.colab import userdata

# %%
import os
from dotenv import load_dotenv
from agents import Agent, Runner, AsyncOpenAI, OpenAIChatCompletionsModel
from agents.run import RunConfig
import asyncio

# Load the environment variables from the .env file
load_dotenv()

gemini_api_key = userdata.get("GEMINI_API_KEY")

# Check if the API key is present; if not, raise an error
if not gemini_api_key:
    raise ValueError("GEMINI_API_KEY is not set. Please ensure it is defined in your .env file.")

#Reference: https://ai.google.dev/gemini-api/docs/openai
external_client = AsyncOpenAI(
    api_key=gemini_api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
)

model = OpenAIChatCompletionsModel(
    model="gemini-2.0-flash",
    openai_client=external_client
)

config = RunConfig(
    model=model,
    model_provider=external_client,
    tracing_disabled=True
)


async def main():
    agent = Agent(
        name="Assistant",
        instructions="You are helpful Assistent.",
        model=model
    )

    result = await Runner.run(agent, "Tell me about recursion in programming.", run_config=config)
    print(result.final_output)
    # Function calls itself,
    # Looping in smaller pieces,
    # Endless by design.


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# Okay, let's dive into recursion in programming.
#
# **What is Recursion?**
#
# Recursion, in its simplest form, is a programming technique where a function calls itself within its own definition. Think of it like a set of Russian nesting dolls (Matryoshka dolls). Each doll contains a smaller version of itself, until you reach the smallest one.  In programming, each function call solves a smaller subproblem of the original problem, until you reach a base case (the smallest doll), which can be solved directly.
#
# **Key Concepts and Terminology**
#
# 1.  **Base Case (Stopping Condition):**  This is the most crucial part of recursion.  It's the condition that tells the function when to *stop* calling itself.  Without a base case, a recursive function would call itself infinitely, leading to a stack overflow error (more on that later).
#
# 2.  **Recursive Step (Recursive Call):** This is where the function calls itself with a modified version of the input.  The input should be modified in a way that brings it closer to the base case.
#
# 3.  **Call Stack:** When a function is called, the program stores information about that call (local variables, return address, etc.) on a stack called the call stack.  Each recursive call adds a new frame to the call stack.  Once the base case is reached, the function calls start returning, and the stack is unwound.
#
# **How Recursion Works (Step-by-Step)**
#
# 1.  A recursive function is initially called with some input.
#
# 2.  The function checks if the input satisfies the base case.
#
#     *   If it does, the function returns a value directly, and the recursion stops for that branch.
#
#     *   If it doesn't, the function performs some computation and then calls itself (the recursive step) with a modified input that is closer to the base case.
#
# 3.  The recursive call executes in the same way, checking for the base case, and either returning or calling itself again.
#
# 4.  This process continues until the base case is reached for all branches of the recursion.
#
# 5.  Once the base cases are reached, the function calls start returning, passing values back up the call stack.
#
# 6.  The initial function call eventually receives the result from its recursive calls, performs any final computation, and returns the final result.
#
# **Example: Factorial Calculation**
#
# Let's illustrate recursion with a classic example: calculating the factorial of a number. The factorial of a non-negative integer `n` (denoted as `n!`) is the product of all positive integers less than or equal to `n`.  For example, 5! = 5 * 4 * 3 * 2 * 1 = 120.
#
# ```python
# def factorial(n):
#   """
#   Calculates the factorial of a non-negative integer using recursion.
#
#   Args:
#     n: The non-negative integer for which to calculate the factorial.
#
#   Returns:
#     The factorial of n.
#   """
#   if n == 0:  # Base case: factorial of 0 is 1
#     return 1
#   else:
#     return n * factorial(n - 1)  # Recursive step: n! = n * (n-1)!
#
# # Example usage
# result = factorial(5)
# print(f"The factorial of 5 is: {result}") # Output: The factorial of 5 is: 120
# ```
#
# **Explanation:**
#
# *   **Base Case:** `if n == 0: return 1`  The factorial of 0 is defined as 1. This is our stopping condition.
# *   **Recursive Step:** `else: return n * factorial(n - 1)`  The factorial of `n` is `n` multiplied by the factorial of `n-1`. This breaks the problem down into a smaller, similar subproblem.
#
# **How the factorial(5) call works:**
#
# 1.  `factorial(5)` is called. `n` is 5, which is not 0, so the `else` block is executed.
# 2.  `return 5 * factorial(4)`  We need to calculate `factorial(4)` first.
# 3.  `factorial(4)` is called. `n` is 4, which is not 0, so the `else` block is executed.
# 4.  `return 4 * factorial(3)`  We need to calculate `factorial(3)` first.
# 5.  `factorial(3)` is called. `n` is 3, which is not 0, so the `else` block is executed.
# 6.  `return 3 * factorial(2)`  We need to calculate `factorial(2)` first.
# 7.  `factorial(2)` is called. `n` is 2, which is not 0, so the `else` block is executed.
# 8.  `return 2 * factorial(1)`  We need to calculate `factorial(1)` first.
# 9.  `factorial(1)` is called. `n` is 1, which is not 0, so the `else` block is executed.
# 10. `return 1 * factorial(0)`  We need to calculate `factorial(0)` first.
# 11. `factorial(0)` is called. `n` is 0, which *is* 0, so the `if` block is executed.
# 12. `return 1`  This is the base case!  `factorial(0)` returns 1.
# 13. Now the stack unwinds:
#     *   `factorial(1)` receives 1 and returns `1 * 1 = 1`
#     *   `factorial(2)` receives 1 and returns `2 * 1 = 2`
#     *   `factorial(3)` receives 2 and returns `3 * 2 = 6`
#     *   `factorial(4)` receives 6 and returns `4 * 6 = 24`
#     *   `factorial(5)` receives 24 and returns `5 * 24 = 120`
#
# Finally, `factorial(5)` returns 120, which is the correct result.
#
# **Advantages of Recursion**
#
# *   **Elegance and Readability:**  For certain problems, recursion can lead to very concise and elegant solutions that are easier to understand than iterative solutions. This is especially true for problems that are naturally defined recursively, such as tree traversals, graph algorithms, and some mathematical functions.
# *   **Problem Decomposition:** Recursion breaks down a complex problem into smaller, self-similar subproblems, which can simplify the design and implementation of the solution.
# *   **Natural Fit for Some Data Structures:** Recursion is often a natural way to process recursive data structures like trees and linked lists.
#
# **Disadvantages of Recursion**
#
# *   **Overhead:** Recursive function calls have overhead associated with them. Each call adds a new frame to the call stack, which takes up memory and processing time. This can make recursive solutions less efficient than iterative solutions for some problems.
# *   **Stack Overflow:** If the recursion goes too deep (i.e., the base case is not reached, or the problem is too large), the call stack can overflow, leading to a stack overflow error. This is a common problem with poorly designed recursive functions.
# *   **Debugging:**  Debugging recursive functions can be more challenging than debugging iterative functions because you need to understand the state of the call stack at each level of recursion.
#
# **When to Use Recursion**
#
# Consider using recursion when:
#
# *   The problem can be naturally expressed in a recursive way.
# *   The recursive solution is clear, concise, and easy to understand.
# *   The depth of the recursion is limited, so you don't have to worry about stack overflow.
# *   Performance is not a critical concern.
#
# **When to Avoid Recursion**
#
# Avoid recursion when:
#
# *   The recursive solution is inefficient or difficult to understand.
# *   The depth of the recursion is potentially large, increasing the risk of stack overflow.
# *   An iterative solution is more straightforward and efficient.
#
# **Tail Recursion and Optimization**
#
# *   **Tail Recursion:**  A recursive function is said to be tail-recursive if the recursive call is the very last operation performed in the function. In other words, there's no computation done after the recursive call returns.
#
# *   **Tail Call Optimization (TCO):** Some compilers and interpreters can optimize tail-recursive functions by reusing the existing stack frame for the recursive call. This eliminates the overhead of creating a new stack frame for each call, making tail-recursive functions as efficient as iterative functions. However, many languages (including Python by default) do not implement TCO.
#
# **Example (Tail-Recursive - in languages that support TCO):**
#
# ```
# def factorial_tail_recursive(n, accumulator=1):
#   if n == 0:
#     return accumulator
#   else:
#     return factorial_tail_recursive(n - 1, n * accumulator)
# ```
#
# In this example, the recursive call is the very last thing that happens in the function. The result of the recursive call is immediately returned.  However, as mentioned, Python does *not* automatically optimize tail-recursive functions.
#
# **Alternatives to Recursion**
#
# For problems where recursion is not the best choice, iterative solutions (using loops) are often a better alternative.
#
# **In Summary**
#
# Recursion is a powerful programming technique that can be used to solve a wide range of problems. It's essential to understand the key concepts (base case, recursive step, call stack), its advantages and disadvantages, and when it's appropriate to use recursion versus iteration. Always be mindful of the potential for stack overflow when designing recursive functions.
